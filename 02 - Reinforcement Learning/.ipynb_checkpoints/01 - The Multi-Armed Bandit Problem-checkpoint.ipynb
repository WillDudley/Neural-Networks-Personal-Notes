# %% [markdown]
# # Overview

# %% [markdown]
# The multi-armed bandit problem is a dilemma where we have 3 slot machines, each with their own win rate. How should we play to maximise our returns? ie. how do we find out which slot machine is best?
#
# We need to find a way of balancing our exploration (collection of data, costly) with our exploitation (playing the machine we currently think is the best). Too much exploration is costly and too little exploration may lead to the wrong conclusion.
#
# One approach could predetermine an immutable number of games to play as exploration to establish statistical significance (A/B testing). However, often the \[minimum\] number of games needed depends on things such as win rates, which obvs we don't know. This is a disadvantage. We will not be caring about statistical significance in this course, and instead look for better ways, balancing the exploration/exploitation trade-off.

# %% [markdown]
# # First way: Epsilon-Greedy

# %% [markdown]
# The simplest way of balance is using the Epsilon-Greedy algorithm for some small epsilon (say, 0.05 or 0.1). It's summarised as follows:

# %%
p = random()

if p < eps:
    pull(random_arm)
else:
    pull(current_arm)

# %% [markdown]
# This will eventually converge to finding/pulling the best arm most of the time. Obvs not the best as it will always pull a random arm sometimes, so it'd be cool to find a method that addresses this. We could combine this with an A/B test, but there are better ways...

# %% [markdown]
# (One solution is to use a decaying epsilon $\varepsilon (t) = 1/t$)

# %% [markdown]
# # Updating a Sample Mean

# %% [markdown]
# When dealing with dynamic means we can simply calculate the mean using $\overline{X} = \dfrac{1}{N} \sum_i=1^N X_i$ every piece of data we collect. However, this involves summing over all $X_i$ every step. There's a much more efficient way to deal with dynamic means.
#
# Indeed:
# $$\overline{X}_N = \dfrac{1}{N} \sum_{i=1}^N X_i = \dfrac{1}{N} \sum_{i=1}^{N-1} X_i + \dfrac{1}{N} X_{N} = \dfrac{N-1}{N} \overline{X}_{N-1} + \dfrac{1}{N} X_{N},$$
# thus
# $$\overline{X}_N = \left( 1 - \dfrac{1}{N} \right) \overline{X}_{N-1} \dfrac{1}{N} X_{N}.$$
#
# Very cool! Much important!

# %% [markdown]
# # Comparing Different Epsilons

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


class Bandit:
    def __init__(self,m):
        self.m = m
        self.mean = 0
        self.N = 0
        self.last_pull = 0

    def pull(self):
        self.last_pull = np.random.randn() + self.m
        self.N += 1
        self.mean = (1 - (1 / self.N) ) * self.mean + 1 / (self.N) * self.last_pull
        return self.last_pull


def run(m1, m2, m3, eps, N):
    bandits = [Bandit(m1),Bandit(m2),Bandit(m3)]
    data = []

    for x in range(N):
        #eps-greedy
        if np.random.random() < eps:
            data.append(bandits[np.random.randint(0,3)].pull())
        else:
            data.append(bandits[np.argmax([b.mean for b in bandits])].pull())


    cum_avg = np.cumsum(data) / (np.arange(N) + 1)

    plt.plot(cum_avg)
    plt.plot(np.ones(N) * m1)
    plt.plot(np.ones(N) * m2)
    plt.plot(np.ones(N) * m3)

    for b in bandits:
        print(b.mean)

    return cum_avg

if __name__ == '__main__':
    c_1 = run(1.0,2.0,3.0,0.1,100000)
    c_05 = run(1.0, 2.0, 3.0, 0.05, 100000)
    c_01 = run(1.0, 2.0, 3.0, 0.01, 100000)

    # log scale plot
    plt.plot(c_1, label='eps = 0.1')
    plt.plot(c_05, label='eps = 0.05')
    plt.plot(c_01, label='eps = 0.01')
    plt.legend()
    plt.xscale('log')
    plt.show()

    # linear plot
    plt.plot(c_1, label='eps = 0.1')
    plt.plot(c_05, label='eps = 0.05')
    plt.plot(c_01, label='eps = 0.01')
    plt.legend()
    plt.show()
# Out:
# 0.9707959251370034
# 2.0294677346738674
# 2.9989070739204124
# 0.9911676194230237
# 2.0174628725516457
# 2.9985634846604103
# 0.9312197555852935
# 2.0159798320465594
# 2.999396863149165

# %% [markdown]
# # Second way: Optimistic Initial Values

# %% [markdown]
# Another approach is to set the initial means to ceilings that are obviously higher than the true means (eg. 10). These means are "too good to be true", so as we explore more and more they will eventually decrease and the algorithm will converge to the highest true mean.
#
# As Optimistic Initial Values doesn't have Epsilon-Greedy's problem of always having a chance of choosing a random bandit, it performs slightly better. The time to converge is pretty much the same (it just converges closer to the true mean).
#
# The code of this is very similar to epsilon-greedy, with only two changes - the initial value of the mean and the actual algorithm itself!

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


class Bandit:
    def __init__(self,m,upper_limit):
        self.m = m
        self.mean = upper_limit
        self.N = 0
        self.last_pull = 0

    def pull(self):
        self.last_pull = np.random.randn() + self.m
        self.N += 1
        self.mean = (1 - (1 / self.N) ) * self.mean + 1 / (self.N) * self.last_pull
        return self.last_pull


def run(m1, m2, m3, N, upper_limit):
    bandits = [Bandit(m1,upper_limit),Bandit(m2,upper_limit),Bandit(m3,upper_limit)]
    data = []

    for x in range(N):
        #Optimistic IV
        data.append(bandits[np.argmax([b.mean for b in bandits])].pull())


    cum_avg = np.cumsum(data) / (np.arange(N) + 1)

    plt.plot(cum_avg)
    plt.plot(np.ones(N) * m1)
    plt.plot(np.ones(N) * m2)
    plt.plot(np.ones(N) * m3)

    for b in bandits:
        print(b.mean)

    return cum_avg

if __name__ == '__main__':
    oiv = run(1.0,2.0,3.0,100000,10)

    # log scale plot
    plt.plot(oiv, label='Optimistic IV')
    plt.legend()
    plt.xscale('log')
    plt.show()

    # linear plot
    plt.plot(oiv, label='Optimistic IV')
    plt.legend()
    plt.show()
# Out:
# 0.6963472305884577
# 2.3226923485291793
# 3.0012226446034296

# %% [markdown]
# # Third way - UCB1 (Upper Confidence Bound)

# %% [markdown]
# Yet another way is to use UCB, relying on the idea of confidence bounds (where taking more samples reduces uncertainty in the probability distribution). For UCB1 we use the Chernoff-Hoeffding bound, which says that the UCB changes exponentially with the number of samples taken:
# $$P \left\lbrace \left\vert \overline{X} - \mu \right\vert \geq \varepsilon \right\rbrace \leq 2 e^{-2 \varepsilon^2 N}.$$
#
# We trust that this result directly leads to the algorithm
# $$X_{\text{UCB}-j} = \overline{X}_j + \sqrt{2 \dfrac{\log N}{N_j}},$$
# where $N = \text{total number of plays}$ and $N_j = \text{number of plays against bandit } j$.

# %% [markdown]
# We utilize this by always being greedy (as in the Optimistic Initial Values method), but instead of being greedy w.r.t $\overline{X}_j$, we're greedy w.r.t $X_{UCB-j}$.

# %% [markdown]
# ### What's the intuition behind this?

# %% [markdown]
# Key Point 1: When $N_j$ is small, the upper bound is high and when $N_j$ is large, the upper bound is low.
#
# Key Point 2: As $\log N$ grows more slowly than $N_j$, eventually all upper bounds will shrink. By then we've explored lots, so that's good.
#
# Hence we converge to a purely greedy strategy.

# %% [markdown]
# We implement this by same way as the OIV method, but simply changing

# %%
    for x in range(N):
        #Optimistic IV
        data.append(bandits[np.argmax(
            [b.mean for b in bandits])].pull())

# %% [markdown]
# to

# %%
def UCB(mean, N, Nj):
    if Nj == 0:
        return float('inf')
    else:
        return mean + np.sqrt(2*np.log(N) / Nj)


#...
    for x in range(N):
        #UCB1
        data.append(bandits[np.argmax(
            [UCB(b.mean, x+1, b.N) for b in bandits])].pull())

# %% [markdown]
# Clearly, as above shows, we address the situation where $N_j$ equals zero by instead treating it as a very small number, hence $X_{UCB-j}$ becomes very large.

# %% [markdown]
# # Fourth way - Bayesian Sampling (AKA Thompson Sampling)

# %% [markdown]
# Note that the mean $\mu$ always has a distribution because $\mu$ is a sum of RVs. Usually, $\mu$ is a fixed constant.
#
# However, Bayesian Sampling treats $\mu$ as a random variable, so we want to find the distribution of the parameters given the data we know (which is fixed). This distribution should clearly be more accurate than if we didn't have the data. We call this distribution the posterior distribution, $p(\theta | X)$.
#
# Bayes' rule is used here to show that
# $$p(\theta | X) \propto p(X | \theta) p(\theta) = \text{likelihood} \times \text{prior}$$
#
# A handy way to do these is with conjugate priors (reference https://en.wikipedia.org/wiki/Conjugate_prior#Table_of_conjugate_distributions) - every distribution/likelihood has a conjugate prior (where the prior is the same form/distribution as the posterior)!
#
# We will now go through an example using a Gaussian (Normal) likelihood.

# %% [markdown]
# #### Step One

# %% [markdown]
# We look at the link provided and find that the Gaussian likelihood with known precision (inverse variance) has a Gaussian conjugate prior.
#
# So our likelihood has the distribution
# $$X \sim N(\mu, \tau^{-1})$$
#
# and our mean $\mu$ (which we are investigating) also has the distribution
# $$\mu \sim N(m_0, \lambda_0^{-1}).$$
#
# Our objective is to iteratively update equations for $m$ and $\lambda$.

# %% [markdown]
# #### Step Two

# %% [markdown]
# Multiply the likelihood and posterior to get the proportionality:

# %% [markdown]
# $$P(\mu | X) \propto \left[ \prod_{n=1}^N \dfrac{1}{\sqrt{2\pi/\tau}} e^{-\dfrac{\tau}{2}(x_n-\mu)^2} \right] \dfrac{1}{\sqrt{2\pi/\lambda_0}} e^{-\dfrac{\lambda_0}{2}(\mu-m_0)^2}$$

# %% [markdown]
# #### Step Three

# %% [markdown]
# Drop the constants (those which are constant w.r.t $\mu$):

# %% [markdown]
# $$P(\mu | X) \propto \exp \left( - \dfrac{\lambda_0}{2} (\mu - m_0)^2 - \dfrac{\tau}{2} \sum_{n=1}^N (x_n^2 - 2x_n \mu + \mu^2) \right)$$

# %% [markdown]
# $$P(\mu | X) \propto \exp \left( - \dfrac{\lambda_0}{2} (\mu^2 - 2\mu m_0) - \mu \dfrac{\tau}{2} \sum_{n=1}^N (- 2x_n) - \mu^2 \dfrac{\tau N}{2} \right)$$

# %% [markdown]
# $$P(\mu | X) \propto \exp  \left( \mu^2 \left( - \dfrac{N\tau}{2} - \dfrac{\lambda_0}{2} \right) - \mu \left( \dfrac{\tau}{2} \sum_{n=1}^N (-2x_n) + m_0 \lambda_0 \right) \right) $$

# %% [markdown]
# $$P(\mu | X) \propto \exp \left[ - \left( \mu^2 \left( \dfrac{N\tau}{2} + \dfrac{\lambda_0}{2} \right) + \mu \left( \tau \sum_{n=1}^N (-x_n) + m_0 \lambda_0 \right) \right) \right]$$

# %% [markdown]
# $$P(\mu | X) \propto \exp \left[ - \dfrac{1}{2} \left( \left( N\tau + \lambda_0 \right) \mu^2 - 2 \left( m_0 \lambda_0 + \tau \sum_{n=1}^N (x_n) \right) \right) \mu + \dotsc \right]$$

# %% [markdown]
# #### Step Four

# %% [markdown]
# We want the form in the exponent of the posterior (and thus conjugate prior). In this case, this is:
# $$ -\dfrac{\lambda}{2}(\mu-m)^2 = - \dfrac{1}{2} (\lambda \mu^2 - 2 m \lambda \mu + \dotsc ). $$
# But this is what we've just found!

# %% [markdown]
# We then equate coefficients of $\mu$ from this step and the last step:
# $$\lambda = N \tau + \lambda_0 .$$
#
#
# $$m \lambda = m_0 \lambda_0 + \tau \sum_{n=1}^N (x_n),$$
# $$m = \dfrac{m_0 \lambda_0 + \tau \sum_{n=1}^N (x_n)}{\lambda} = \dfrac{m_0 \lambda_0 + \tau \sum_{n=1}^N (x_n)}{N \tau + \lambda_0} .$$

# %% [markdown]
# At last, we have equations for the new $\lambda$ and the new $m$, based on the prior parameters and the new data we've collected.

# %% [markdown]
# ## Application to the Bandit Problem

# %% [markdown]
# Rather than choose the UCB as in UCB1, we choose the argmax of our samples of each bandit's mean (the means are now probability distributions, so we can draw samples from them).
#
# It should be easy to see how the Bayesian posterior automatically controls the exploration-exploitation trade-off.

# %% [markdown]
# From https://stats.stackexchange.com/questions/58564/help-me-understand-bayesian-prior-and-posterior-distributions:
#
# <u> These rules of thumb follow directly from the nature of the Bayesian analysis procedure: </u>
#
# <ol>
#     <li>If the prior is uninformative, the posterior is very much determined by the data (the posterior is data-driven).</li>
#
#     <li>If the prior is informative, the posterior is a mixture of the prior and the data.</li>
#
#     <li>The more informative the prior, the more data you need to "change" your beliefs, so to speak because the posterior is very much driven by the prior information.</li>
#
#     <li>If you have a lot of data, the data will dominate the posterior distribution (they will overwhelm the prior).</li>
# </ol>

# %% [markdown]
# # Which way is best?

# %% [markdown]
# Actually, (when using Decaying-Epsilon-Greedy instead of Epsilon-Greedy), it turns out that all four algorithms perform the same! They all converge at the same time (at least in The Multi-Armed Bandit Problem) and when time is large they actually all intertwine with each other with no obvious victor.
#
# For this reason, we proceed with Decaying-Epsilon-Greedy for all our exploration-exploitation trade-off needs :)

# %% [markdown]
# ![Comparison of Algorithms (log scale)](01 - explore-exploit-comparisons.png)

# %% [markdown]
# Bear in mind that the above graph relies on randomness and is not a proof that, for example, UCB1 converges slower than Bayesian Sampling.

# %% [markdown]
# # Nonstationary Bandits

# %% [markdown]
# The following is important stuff that will be used throughout the course.

# %% [markdown]
# A stationary process is a process whose statistics (eg. mean) are independent of time.
#
#    <b>Weak-sense stationary</b>: Mean (first order statistic) and autocovariance (second order statistic) are independent of time.
#
#    <b>Strong-sense stationary</b>: Entire PDF is independent of time.
#
# With the bandits, we have strong-sense stationary processes. This begs the question; what if the bandits are nonstationary? Do we still calculate the mean as before?

# %% [markdown]
# Recall from previously that
# $$\overline{X}_N = \left( 1 - \dfrac{1}{N} \right) \overline{X}_{N-1} \dfrac{1}{N} X_{N}.$$
#
# Trust that it's convenient to rearrange this as
# $$Q_t = Q_{t-1} - \alpha (Q_{t-1} - X_t), \qquad Q_t = \overline{X}_t, \quad \alpha = \dfrac{1}{t},$$
# where we call $\alpha$ the "learning rate", which can be set as anything (including constants).

# %% [markdown]
# Another common equation in ML is the Low Pass Filter:
# $$Q_t = (1-\alpha) Q_{t-1} + \alpha X_t .$$
# This is written after getting rid of recurrence as:
# $$Q_t = \alpha \sum_{\tau = 0}^t (1-\alpha)^\tau X_{t-\tau}.$$
# From this we see that $Q$ has an exponentially decaying dependence on $X$, so it has more emphasis on recent values.
#
# This equation, for example, can be used to reduce noise in a recieved wave.

# %% [markdown]
# ## Convergence Criteria for Q

# %% [markdown]
# $Q$ will converge if
# $$\sum_{t=1}^\infty \alpha(t) = \infty, \qquad \sum_{t=1}^\infty \alpha(t)^2 < \infty .$$
#
# Some basic results of this are that constant $\alpha$ doesn't converge, and that $\alpha = \dfrac{1}{t}$ does converge.
#
# If we have a problem that is nonstationary, we wouldn't want convergence (as in a nonstationary/dynamic problem it doesn't make sense to have equal weighting in all samples), so we would use a constant $\alpha$.*
#
# *If $Q$ converges, then the estimated mean of $X$ converges, which isn't what we want in a nonstationary system (where the mean changes over time)!!
